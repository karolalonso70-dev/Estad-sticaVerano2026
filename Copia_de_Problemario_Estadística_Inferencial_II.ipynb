# %% [markdown]
# <a href="https://colab.research.google.com/github/karolalonso70-dev/Estad-sticaVerano2026/blob/main/Copia_de_Problemario_Estad%C3%ADstica_Inferencial_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{yy} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame(
    {"promedio_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
         "promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
                            })
df
# Out:
#     promedio_examenes_cortos  promedio_final
# 0                         59              64
# 1                         92              84
# 2                         72              77
# 3                         90              80
# 4                         95              77
# 5                         87              81
# 6                         89              80
# 7                         77              84
# 8                         76              80
# 9                         65              69
# 10                        97              83
# 11                        42              40
# 12                        94              78
# 13                        62              65
# 14                        91              90

# %% [markdown]
# **1. Establesca una variable dependiente ($Y$) y una variable inependiente ($X$)**
#
# + $Y$: es promedio final.
# + $X$: es promedio examenes cortos.

# %%
# Que informacion tengo (x) Variable independiente
# Que informacion tengo (y) Variable dependiente
y= df ['promedio_final']
x= df ['promedio_examenes_cortos']

# %% [markdown]
# **2. Realice un diagrama de dispersión para estos datos.**

# %%
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    x, y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='purple',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'promedio examenes cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'promedio final', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **4.Calcule el coeficiente de correlación e interprete el resultado.**

# %%
import pandas as pd
from scipy.stats import pearsonr

df = pd.DataFrame(
{"promedio_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
"promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]})

X = df["promedio_examenes_cortos"]
Y = df["promedio_final"]

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.8646
# valor_p:  0.0000

# %% [markdown]
# **5. Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

modelo.params
# Out:
# const                       24.526822
# promedio_examenes_cortos     0.643180
# dtype: float64

# %% [markdown]
# El modelo es:
#
# $$
# \hat{y}=24.526822+0.643180x
# $$
# donde $x$ es el promedio en exámenes cortos.

# %%
#modelo.predict([1.x])

modelo.predict([1,59])
# Out:
# array([62.47443345])

# %% [markdown]
# **6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),
    dpi=120
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",
    color='purple',
    edgecolor='purple',
    alpha=0.9,
    s=50,
)

# Gráfico de línea
plt.plot(
    X, y_calculadora,
    color='black',
    linewidth=1.0,
    linestyle='--',
    label='Recta de regresión'
)

# Etiquetas de los ejes
plt.xlabel(
    'Promedio Examenes Cortos',
    fontsize=12
)

plt.ylabel(
    'Pomedio Final',
    fontsize=12
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %%
import pandas as pd
import statsmodels.api as sm

df = pd.DataFrame(
    {"promedio_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
     "promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
    })

X = df["promedio_examenes_cortos"]
Y = df["promedio_final"]

x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()

residuales = modelo.resid

# %% [markdown]
# **8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
import matplotlib.pyplot as plt

# --- Re-definición de dependencias debido a NameError ---
import pandas as pd
df = pd.DataFrame(
{"promedio_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
"promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]})
X = df["promedio_examenes_cortos"]
Y = df["promedio_final"]

import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

residuales = modelo.resid
# --- Fin de la re-definición de dependencias ---

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),
    dpi=120
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="*",
    color='purple',
    edgecolor='purple',
    alpha=0.9,
    s=50,
)

# Gráfico de línea
plt.plot(
    X, y_calculadora * 0, #
    color='black',
    linewidth=1.0,
    linestyle='--',
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Promedio Examenes Cortos',
    fontsize=12
)

plt.ylabel(
    'Residuales',
    fontsize=12
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **9. Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# test de Shapiro-Wilk
# HO Hay normalidad
#H1: No hay normalidad

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.901827735700704

# %% [markdown]
# **10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.2289

# %% [markdown]
# **12. Realice una tabla ANOVA e interprete el resultado.**

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('''promedio_final ~ promedio_examenes_cortos''', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                             df       sum_sq      mean_sq          F    PR(>F)
# promedio_examenes_cortos   1.0  1538.228959  1538.228959  38.492412  0.000032
# Residual                  13.0   519.504375    39.961875        NaN       NaN

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame(
{"categorias de salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
"ausencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]})
df
# Out:
#     categorias de salario  ausencias
# 0                      11         18
# 1                      10         17
# 2                       8         29
# 3                       5         36
# 4                       9         11
# 5                       7         28
# 6                       3         35
# 7                      11         14
# 8                       8         20
# 9                       7         32
# 10                      2         39
# 11                      9         16
# 12                      8         31
# 13                      3         40

# %% [markdown]
# **1. Establesca una variable dependiente ($Y$) y una variable inependiente ($X$)**
#
# + $Y$: e el salario porque
# + $X$: es

# %%
# Qué información tengo (x) Variable independiente
# Qué información predecir (y) Variable dependientes

X= df["ausencias"]
Y= df["categorias de salario"]

# %% [markdown]
# **2. Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='purple',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Categorias de salarios', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **4.Calcule el coeficiente de correlación e interprete el resultado.**

# %%
import pandas as pd
from scipy.stats import pearsonr

df = pd.DataFrame(
{"salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
"aucencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]})

X = df["salario"]
Y = df["aucencias"]

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)


print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.8801
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación es $r=-0.8801$, este valor indica que si aumentan las ausencias $x$ reduce el salario $y$.

# %% [markdown]
# **5. Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculadora)
print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  77.46%

# %% [markdown]
# con coeficiente de determinacion de $r^2=0.7746$ indica que con las auscencias estoy justificando en un 77.46% la variabilidad en los salarios. por lo que el modelo puede tener una buena capacidad de perdiccion.

# %% [markdown]
# **6. obtenga la regla de egrecion ajustada y grafiquelo sobre el grafico de dispercion.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

modelo.params
# Out:
# const        14.058843
# ausencias    -0.261814
# dtype: float64

# %% [markdown]
# El modelo:
#
# $$
# \hat{y}=14.058843+-0.261814x
# $$
# donde $x$ es el promedio en salarios

# %%
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),
    dpi=120
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",
    color='purple',
    edgecolor='purple',
    alpha=0.9,
    s=50,
)

# Gráfico de línea
plt.plot(
    X, y_calculadora,
    color='black',
    linewidth=1.0,
    linestyle='--',
    label='Recta de regresión'
)

# Etiquetas de los ejes
plt.xlabel(
    'Ausencias',
    fontsize=12
)

plt.ylabel(
    'categorias de salarios',
    fontsize=12
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 7. **Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %% [markdown]
# La recta tiene la forma:
#
# $$\hat{y}=b_0+b_1X$$

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const      11.587445  16.530241
# ausencias  -0.350638  -0.172989

# %% [markdown]
# El verdadero $b_0$ está entre $11.587445$ y $16.530241$ con una confianza del 95%. Esto indica que una persona sin ausencias ($X=0$) tiene una categoría de salario ($Y$) que está entre estos dos valores.
#
# El verdadero valor de $b_1$ está entre $-0.350638$ y $-0.172989$ con un 95% de confianza. Dado que dentre de este intervalo no está el valor de cero, entonces la relación es significativa. También indica que por cada falta se pierde entre 0.172989 y 0.350638 en la categoría de salario.

# %% [markdown]
# 8. **Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='#F527D3',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# + linealidad: Parece que si
# + Normalidad: Si cumple con la normaliad.
# + Homoscedasticidad: Si cumple
# + Indepenencia: Si cumple porque son diferentes personas.

# %% [markdown]
# **9. Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, shapiro s el mas confiable-wilk es el ma confiable

# test de Shapiro-Wilk
# HO Hay normalidad
#H1: No hay normalidad

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.4172971767713699

# %% [markdown]
# **10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.8955

# %% [markdown]
# **11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %% [markdown]
# si el modelo cumple con todos los supuestos es confiable para la interpolacion

# %%
import pandas as pd
import statsmodels.api as sm

# Re-initialize df for Problem 2
df = pd.DataFrame(
    {"categorias de salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
     "ausencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]})

# Define X and Y for Problem 2
X = df["ausencias"]
Y = df["categorias de salario"]

# Re-define modelo for Problem 2
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()

# mínimo ausencias: 11
# máximo ausencias: 40

# interpolar, valores de x entre 11 y 40

# interpolar 1
y_11 = modelo.predict([1, 11])
y_40 = modelo.predict([1, 40])

print(f"Para x = 11, y =  {y_11[0]: 0.4f}")
print(f"Para x = 40, y =  {y_40[0]: 0.4f}")
# Out:
# Para x = 11, y =   11.1789
# Para x = 40, y =   3.5863

# %%
df["salario_predicho"] = y_calculadora.round()
df
# Out:
#     categorias de salario  ausencias  salarip_predicho  salario_predicho
# 0                      11         18               9.0               9.0
# 1                      10         17              10.0              10.0
# 2                       8         29               6.0               6.0
# 3                       5         36               5.0               5.0
# 4                       9         11              11.0              11.0
# 5                       7         28               7.0               7.0
# 6                       3         35               5.0               5.0
# 7                      11         14              10.0              10.0
# 8                       8         20               9.0               9.0
# 9                       7         32               6.0               6.0
# 10                      2         39               4.0               4.0
# 11                      9         16              10.0              10.0
# 12                      8         31               6.0               6.0
# 13                      3         40               4.0               4.0

# %% [markdown]
# La extrapolación siempre debe hacerse con cuidado, aunque cumpla con todos los supuestos.

# %%
# mínimo ausencias: 11
# máximo ausencias: 40

# Extrapolar, valores de x entre 11 y 40

y_10 = modelo.predict([[1, 10]])

print(f"Para x = 10, y =  {y_10[0]: 0.4f}")
# Out:
# Para x = 10, y =   11.4407

# %% [markdown]
# Con 10 ausencias se espera que el empleado tenga una categoría de salario de 11. Este valor se obtuvo por medio de extrapolación, por lo que se toma con reservas.

# %% [markdown]
# **12. Realice una tabla ANOVA e interprete el resultado.**

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Redefine df for Problem 2 to ensure correct data is used
df = pd.DataFrame(
    {"salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
     "aucencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]})

# Y ~ X
modelo_lineal = ols(
    '''Q('salario') ~ aucencias''',data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#              df     sum_sq    mean_sq          F    PR(>F)
# aucencias   1.0  87.034348  87.034348  41.243954  0.000033
# Residual   12.0  25.322795   2.110233        NaN       NaN

# %% [markdown]
# Sí hay correlación porque el valor-p de 0.000033 es menor a un nivel de significancia $\alpha=0.05$.

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame(
    {"gastos generales":[191,170,272,155,280,173,234,116,153,178],
         "unidades":[40,42,53,35,56,39,48,30,37,40]
                            })
df
# Out:
#    gastos generales  unidades
# 0               191        40
# 1               170        42
# 2               272        53
# 3               155        35
# 4               280        56
# 5               173        39
# 6               234        48
# 7               116        30
# 8               153        37
# 9               178        40

# %% [markdown]
# **1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).**
#
# + $Y$: es gastos generales
# + $X$: es unidades

# %%
# Qué información tengo (x) Variable independiente
# Qué información predecir (y) Variable dependientes

X= df["unidades"]
Y= df["gastos generales"]

# %% [markdown]
# **2. Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='purple',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'gastos generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **4. Calcule el coeficiente de correlación e interprete el resultado.**

# %%
import pandas as pd
from scipy.stats import pearsonr

df = pd.DataFrame(
    {"gastos generales":[191,170,272,155,280,173,234,116,153,178],
         "unidades":[40,42,53,35,56,39,48,30,37,40]
                            })
X = df["unidades"]
Y = df["gastos generales"]

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)


print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9835
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlacion es $r=0.9835$

# %% [markdown]
# **5. Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculadora)
print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  96.73%

# %% [markdown]
# con el coeficiente de determinacion de $r^2=96.73$

# %% [markdown]
# **6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

modelo.params
# Out:
# const      -80.442857
# unidades     6.491497
# dtype: float64

# %% [markdown]
# El modelo:
#
# $$
# \hat{y}=-80.442857+-6.491497x
# $$
# donde $x$ es el promedio

# %%
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),
    dpi=120
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",
    color='purple',
    edgecolor='purple',
    alpha=0.9,
    s=50,
)

# Gráfico de línea
plt.plot(
    X, y_calculadora,
    color='black',
    linewidth=1.0,
    linestyle='--',
    label='Recta de regresión'
)

# Etiquetas de los ejes
plt.xlabel(
    'unidades',
    fontsize=12
)

plt.ylabel(
    'gastos generales',
    fontsize=12
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 ).**

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const    -121.986373 -38.899341
# unidades    5.518450   7.464543

# %% [markdown]
# **8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, resuales,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='#F527D3',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'gastos generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# **9 .Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, shapiro s el mas confiable-wilk es el ma confiable

# test de Shapiro-Wilk
# HO Hay normalidad
#H1: No hay normalidad

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.22045077017698533

# %% [markdown]
# **10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.9858

# %% [markdown]
# **11. utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
import statsmodels.api as sm
import pandas as pd

# Re-initialize df, X, Y for Problem 3
df = pd.DataFrame(
    {"gastos generales":[191,170,272,155,280,173,234,116,153,178],
         "unidades":[40,42,53,35,56,39,48,30,37,40]
                            })
X = df["unidades"]
Y = df["gastos generales"]

# Re-define modelo for Problem 3
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()

# mínimo unidades: 30
# máximo unidades: 56

# interpolar, valores de x entre 5 y 25

# interpolar 1
y_30 = modelo.predict([1, 30])
y_56 = modelo.predict([1, 56])

print(f"Para x = 30, y =  {y_30[0]: 0.4f}")
print(f"Para x = 56, y =  {y_56[0]: 0.4f}")
# Out:
# Para x = 30, y =   114.3020
# Para x = 56, y =   283.0810

# %% [markdown]
# **12. Realice una tabla ANOVA e interprete el resultado.**

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd

# Re-initialize df for Problem 3
df = pd.DataFrame(
    {"gastos generales":[191,170,272,155,280,173,234,116,153,178],
         "unidades":[40,42,53,35,56,39,48,30,37,40]
                            })

# Y ~ X
modelo_lineal = ols(
    '''Q('gastos generales') ~ unidades''',data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#            df        sum_sq       mean_sq           F        PR(>F)
# unidades  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual  8.0    837.557483    104.694685         NaN           NaN

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame(
{"construccion de casas":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
"ventas de lineas blanca":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]})
df
# Out:
#    construccion de casas  ventas de lineas blanca
# 0                    2.0                      5.0
# 1                    2.5                      5.5
# 2                    3.2                      6.0
# 3                    3.6                      7.0
# 4                    3.7                      7.2
# 5                    4.0                      7.7
# 6                    4.2                      8.4
# 7                    4.6                      9.0
# 8                    4.8                      9.7
# 9                    5.0                     10.0

# %% [markdown]
# **1. Establesca una variable dependiente (Y) y una variable independiente (X).**
#
# + $X$: es construccion de casas
# + $Y$: es ventas de lineas blanca

# %%
# Qué información tengo (x) Variable independiente
# Qué información predecir (y) Variable dependientes

X= df["construccion de casas"]
Y= df["ventas de lineas blanca"]

# %% [markdown]
# **2. Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='purple',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'construccion de casas', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'ventas de lineas blanca', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **4. Calcule el coeficiente de correlación e interprete el resultado.**

# %%
import pandas as pd
from scipy.stats import pearsonr

df = pd.DataFrame(
{"construccion de casas":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
"ventas de lineas blanca":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]})

X = df["construccion de casas"]
Y = df["ventas de lineas blanca"]

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)


print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9808
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación es $r=0.9808$

# %% [markdown]
# **5. Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculadora)
print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  96.19%

# %% [markdown]
# **6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

modelo.params
# Out:
# const                    1.016760
# construccion de casas    1.737564
# dtype: float64

# %% [markdown]
# El modelo:
#
# $$
# \hat{y}=1.016760+1.737564x
# $$
# donde $x$ es el promedio

# %%
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),
    dpi=120
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",
    color='purple',
    edgecolor='purple',
    alpha=0.9,
    s=50,
)

# Gráfico de línea
plt.plot(
    X, y_calculadora,
    color='black',
    linewidth=1.0,
    linestyle='--',
    label='Recta de regresión'
)

# Etiquetas de los ejes
plt.xlabel(
    'construccion de casas',
    fontsize=12
)

plt.ylabel(
    'ventas de lineas blanca',
    fontsize=12
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )**

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                               0         1
# const                 -0.074848  2.108368
# construccion de casas  1.455693  2.019435

# %% [markdown]
# **8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuals = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='#F527D3',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# **9. Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, shapiro s el mas confiable-wilk es el ma confiable

# test de Shapiro-Wilk
# HO Hay normalidad
#H1: No hay normalidad

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.22045077017698533

# %% [markdown]
# **10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.0398

# %% [markdown]
# **11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
# mínimo construccion de casas: 2.0
# maximo constuccion de casa: 5.0

# interpolar, valores de x entre 11 y 40

# interpolar 1
y_25 = modelo.predict([1, 25])
y_32 = modelo.predict([1, 32])

print(f"Para x = 25, y =  {y_25[0]: 0.4f}")
print(f"Para x = 32, y =  {y_32[0]: 0.4f}")
# Out:
# Para x = 25, y =   44.4559
# Para x = 32, y =   56.6188

# %%
import pandas as pd
import statsmodels.api as sm

# Re-define df, X, Y for Problem 4 to ensure correct data is used
df = pd.DataFrame(
{"construccion de casas":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
"ventas de lineas blanca":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]})

X = df["construccion de casas"]
Y = df["ventas de lineas blanca"]

x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

df["salario_predicho"] = y_calculadora.round()
df
# Out:
#    construccion de casas  ventas de lineas blanca  salario_predicho
# 0                    2.0                      5.0               4.0
# 1                    2.5                      5.5               5.0
# 2                    3.2                      6.0               7.0
# 3                    3.6                      7.0               7.0
# 4                    3.7                      7.2               7.0
# 5                    4.0                      7.7               8.0
# 6                    4.2                      8.4               8.0
# 7                    4.6                      9.0               9.0
# 8                    4.8                      9.7               9.0
# 9                    5.0                     10.0              10.0

# %% [markdown]
# **12. Realice una tabla ANOVA e interprete el resultado.**

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Redefine df for Problem 4 to ensure correct data is used
df = pd.DataFrame(
    {"construccion de casas":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
     "ventas de lineas blanca":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]})

# Y ~ X
modelo_lineal = ols(
    '''Q('ventas de lineas blanca') ~ Q('construccion de casas')''',data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                              df     sum_sq    mean_sq           F  \
# Q('construccion de casas')  1.0  25.976581  25.976581  202.069951
# Residual                    8.0   1.028419   0.128552         NaN
#
#                                   PR(>F)
# Q('construccion de casas')  5.841003e-07
# Residual                             NaN

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame(
{"numero interupciones al trabajador":[5,10,10,15,15,20,20,25],
"calificacion del trabajador en la prueba de hostlidad":[58,41,45,27,26,12,16,3]})
df
# Out:
#    numero interupciones al trabajador  \
# 0                                   5
# 1                                  10
# 2                                  10
# 3                                  15
# 4                                  15
# 5                                  20
# 6                                  20
# 7                                  25
#
#    calificacion del trabajador en la prueba de hostlidad
# 0                                                 58
# 1                                                 41
# 2                                                 45
# 3                                                 27
# 4                                                 26
# 5                                                 12
# 6                                                 16
# 7                                                  3

# %% [markdown]
# **1.Establesca una variable dependiente (Y) y una variable independiente (X).**
#
# $Y$: es calificacion del trabajador en la prueba de hostlilidad
#
# $X$: es numero interrupciones al trabajador

# %%
# Qué información tengo (x) Variable independiente
# Qué información predecir (y) Variable dependientes

X = df["numero interupciones al trabajador"]
Y = df["calificacion del trabajador en la prueba de hostlidad"]

# %% [markdown]
# **2. Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='purple',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'numero interupciones al trabajador', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'es calificacion del trabajador en la prueba de hostlilidad', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **4. Calcule el coeficiente de correlación e interprete el resultado.**

# %%
import pandas as pd
from scipy.stats import pearsonr

df = pd.DataFrame(
    {"numero interupciones al trabajador":[5,10,10,15,15,20,20,25],
         "calificacion del trabajador en la prueba de hostlidad":[58,41,45,27,26,12,16,3]
                            })
X = df["numero interupciones al trabajador"]
Y = df["calificacion del trabajador en la prueba de hostlidad"]

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)


print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.9928
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlacion es $r=0.9928$$r=0.9835$, este valor indica

# %% [markdown]
# **5. Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculadora)
print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  98.58%

# %% [markdown]
# **6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculadora = modelo.predict(x_constante)

modelo.params
# Out:
# const                                 70.5
# numero interupciones al trabajador    -2.8
# dtype: float64

# %%
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),
    dpi=120
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="*",
    color='purple',
    edgecolor='purple',
    alpha=0.9,
    s=50,
)

# Gráfico de línea
plt.plot(
    X, y_calculadora,
    color='black',
    linewidth=1.0,
    linestyle='--',
    label='Recta de regresión'
)

# Etiquetas de los ejes
plt.xlabel(
    'numero interupciones al trabajador',
    fontsize=12
)

plt.ylabel(
    'calificacion del trabajador en la prueba de hostlidad',
    fontsize=12
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# **7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada (b1)**

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                                             0          1
# const                               65.051384  75.948616
# numero interupciones al trabajador  -3.136296  -2.463704

# %% [markdown]
# **8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="*",       # forma: googlear "matplotlib.markers"
    color='#F527D3',     # color de los puntos
    edgecolor='purple',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculadora * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'numero interupciones al trabajador', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'calificacion del trabajador en la prueba de hostlidad', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# **9. Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, shapiro s el mas confiable-wilk es el ma confiable

# test de Shapiro-Wilk
# HO Hay normalidad
#H1: No hay normalidad

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.054816491127669634

# %% [markdown]
# **10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.2482

# %% [markdown]
# **11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
import statsmodels.api as sm

# mínimo numero interupciones al trabajador: 5
# máximo numero interupciones al trabajador: 25

# interpolar, valores de x entre 5 y 25

# interpolar 1
y_10 = modelo.predict([1, 10])
y_20 = modelo.predict([1, 20])

print(f"Para x = 10, y =  {y_10[0]: 0.4f}")
print(f"Para x = 20, y =  {y_20[0]: 0.4f}")
# Out:
# Para x = 10, y =  -15.5279
# Para x = 20, y =   49.3871

# %% [markdown]
# **12. Realice una tabla ANOVA e interprete el resultado.**

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd

# Re-initialize df for Problem 5
df = pd.DataFrame(
    {"numero interupciones al trabajador":[5,10,10,15,15,20,20,25],
"calificacion del trabajador en la prueba de hostlidad":[58,41,45,27,26,12,16,3]})

# Y ~ X
modelo_lineal = ols(
    '''Q('calificacion del trabajador en la prueba de hostlidad') ~ Q('numero interupciones al trabajador')''',data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                           df  sum_sq      mean_sq           F  \
# Q('numero interupciones al trabajador')  1.0  2352.0  2352.000000  415.058824
# Residual                                 6.0    34.0     5.666667         NaN
#
#                                                PR(>F)
# Q('numero interupciones al trabajador')  9.090964e-07
# Residual                                          NaN
